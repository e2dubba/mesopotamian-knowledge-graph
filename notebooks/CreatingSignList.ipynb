# %%
import pandas as pd

etcsl_url = 'http://etcsl.orinst.ox.ac.uk/edition2/signlist.php'

df = pd.read_html(etcsl_url)

# %%
df = df[2]

# %%
df
# Out:
#                                                  0      1  \
# 0                                       Sign names  Signs
# 1                                                A    NaN
# 2                                             A.AN    NaN
# 3                                       A.EDIN.LAL    NaN
# 4                                      A.HA.TAR.DU    NaN
# 5                                            A.IGI    NaN
# 6                                             A.KA    NaN
# 7                                            A.KAL    NaN
# 8                                        A.LAGAB×A    NaN
# 9                       A.LAGAB×HALBorger: A.ENGUR    NaN
# 10                      A.LAGAB×KULBorger: A.ESIR2    NaN
# 11                                       A.MUŠ3.DI    NaN
# 12                                     A.MUŠ3×A.DI    NaN
# 13   A.PA.GISAL.PAD.SI.ABorger: A.PA.GISAL.PAD.DIR    NaN
# 14                                            A.SU    NaN
# ...

# %%
df[df[2].str.contains('sig')]
# Out:
#                             0    1  \
# 158  EZEN×KU3Borger: EZEN×KUG  NaN
# 202                        GI  NaN
# 279     IGI.ERIN2Borger: SIG5  NaN
# 289       IGIgunuBorger: SIG7  NaN
# 327                    KA×ŠID  NaN
# 506                        PA  NaN
# 570                       SAR  NaN
# 571                        SI  NaN
# 574                       SIG  NaN
# 585                       SUM  NaN
#
#                                                      2
# 158                                             kisiga
# 202                      ge, gen6, gi, ke2, ki2, sig17
# 279                                 kur7, kurum7, sig5
# 289                      imma3, se12, sig7, šex, ugur2
# 327                                        sigx, šeg10
# 506  ĝidru, ḫendur, kumx, kun2, mu6, mudru, pa, sag...
# 570   kiri6, mu2, nisig, saḫar2, sakar, sar, sigx, šar
# 571                                           si, sig9
# 574                                si11, sig, sik, šex
# ...

# %%
df.iloc[574][0]
# Out:
# 'SIG'
